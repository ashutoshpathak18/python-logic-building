# %%
# Count Character

num = input("Enter a string :")
count = 0

for i in num:
    count+=1
print(f"{num} has {count} character ")
# Out:
# ashu has 4 character

# %%
# Count vowels

num = input("Enter a string :")
count = 0

for i in num:
    if i in ('a','e','i','o','u','A','E','I','O','U'):
      count+=1   
print(f"{num} has {count} vowel ")
# Out:
# Ashutosh has 3 vowel

# %%
# reverse the string

str = input("Enter the string :")
rev_str = ''
for i in str
